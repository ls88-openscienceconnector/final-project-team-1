# %%
# from datascience import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# import data.table
# source("util/plotting.R")
# import ggplot2
# from ggplot import *
# from pandas import Timestamp
# import ggplot
# library(prophet)
# library(changepoint)
# library(lubridate)
# library(Hmisc)
# source("util/plotting.R")

# theme_set(my_custom_theme(

# %% [markdown]
# ### Loading Data from CSV

# %%
# To generate figure 1, we need to load these data set
daily_counts_exposures = pd.read_csv('daily_counts_exposures.csv')
daily_counts_exposures_guess = pd.read_csv('daily_counts_exposures_guess.csv')
daily_counts_shares = pd.read_csv('daily_counts_shares.csv')
display(daily_counts_exposures_guess.head(5))
display(daily_counts_exposures.head(5))
display(daily_counts_shares.head(5))
# Out:
#    ts_rel_days  red  orange  black        N        date  pct_red  pct_orange  \
# 0          -95    0       0   5481   407325  2016-08-05        0           0
# 1          -76    0       0   5952   419891  2016-08-24        0           0
# 2            2    0       0   8253   958011  2016-11-10        0           0
# 3            9    0       0   6090   616945  2016-11-17        0           0
# 4            1    0       0   6945  1262925  2016-11-09        0           0
#
#    pct_black  pct_fake
# 0   0.013456  0.013456
# 1   0.014175  0.014175
# 2   0.008615  0.008615
# 3   0.009871  0.009871
# 4   0.005499  0.005499
#    ts_rel_days    red  orange  black        N        date   pct_red  \
# 0          -95  11071    7862   2608   407325  2016-08-05  0.027180
# 1          -76   9478    8275   2386   419891  2016-08-24  0.022573
# 2            2  13771   10922   2224   958011  2016-11-10  0.014375
# 3            9  10661    9070   2961   616945  2016-11-17  0.017280
# 4            1  11943   10562   1782  1262925  2016-11-09  0.009457
#
#    pct_orange  pct_black  pct_fake
# 0    0.019302   0.006403  0.052884
# 1    0.019707   0.005682  0.047962
# 2    0.011401   0.002321  0.028097
# 3    0.014701   0.004799  0.036781
# 4    0.008363   0.001411  0.019231
#    ts_rel_days  red  orange  black     N        date   pct_red  pct_orange  \
# 0            0   57      45     20  2769  2016-11-08  0.020585    0.016251
# 1            8    3       6      2   299  2016-11-16  0.010033    0.020067
# 2          -89   11      14     33   597  2016-08-11  0.018425    0.023451
# 3           13    7       7      1   706  2016-11-21  0.009915    0.009915
# 4           20   10       8      6   530  2016-11-28  0.018868    0.015094
#
#    pct_black  pct_fake
# 0   0.007223  0.044059
# 1   0.006689  0.036789
# 2   0.055276  0.097152
# 3   0.001416  0.021246
# 4   0.011321  0.045283

# %% [markdown]
# # Exploratory Data Analysis

# %%
daily_counts_exposures_guess.plot(x='pct_red',  kind='bar')
